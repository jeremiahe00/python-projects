# %%
from PIL import Image

# %%
aizen = Image.open('aizen_image.jpg')

# %%
aizen.putalpha(128)

# %%
aizen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=250x188 at 0x17C959683D0>

# %%
aizen.save("aizen_aplha.png")

# %%
masked = Image.open('mask.png')
word_matrix = Image.open('word_matrix.png')

# %% [markdown]
# mask

# %%
masked.size
# Out:
# (505, 251)

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
masked=masked.resize((1015,559))

# %%
masked.size
# Out:
# (1015, 559)

# %%
masked.putalpha(255)

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x17C988ACA00>

# %%
masked.paste(im=word_matrix,box=(0,0), mask=word_matrix)

# %%
masked
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x17C97E79A30>

# %%
word_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x17C97E798E0>
